# %% [markdown]
# <a href="https://colab.research.google.com/github/fazelelham32/YouTube-Projects/blob/CNN-Projects-google-colab/chapter5_a_simple_two_layer_neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
class neural_network:
  def __init__(self, n_input, n_nroun):
    self.weights = 0.01 * np.random.randn(n_input, n_nroun)
    self.biases = 0.01 * np.random.randn(1, n_nroun)

  def Dense(self, z):
    # Transpose the input z to align the shapes for matrix multiplication
    output = np.dot(z, self.weights) + self.biases
    return output

dense1 = neural_network(2, 4)
x_input = np.array([[0.3, 0.9]])
output1 = dense1.Dense(x_input)
print(output1)
# Out:
# [[ 0.0155156   0.014653    0.02319029 -0.01072799]]

# %%
dense2 = neural_network(4, 8)
output2 = dense2.Dense(output1)
print(output2)
# Out:
# [[-0.00690276 -0.0017147  -0.02397941  0.00383578 -0.00764991  0.00714319
#    0.01190604 -0.00473588]]

# %% [markdown]
# project2
