# %% [markdown]
# <a href="https://colab.research.google.com/github/fazelelham32/YouTube-Projects/blob/CNN-Projects-google-colab/Copy_of_NN_chapter2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
input_value = np.array([0.5, 0.8, 0.06])
input_value
# Out:
# array([0.5 , 0.8 , 0.06])

# %%
weights = np.array([0.02, 0.32, 0.98])
weights
# Out:
# array([0.02, 0.32, 0.98])

# %%
output = np.dot(input_value, weights.T)
output
# Out:
# np.float64(0.32480000000000003)
