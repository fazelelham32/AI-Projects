# %% [markdown]
# <a href="https://colab.research.google.com/github/fazelelham32/YouTube-Projects/blob/CNN-Projects-google-colab/NN_chapter1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **project1**

# %%
import numpy as np

# %%
input_value = np.array([5])

# %%
input_value
# Out:
# array([5])

# %%
weights = np.array([0.4])

# %%
weights
# Out:
# array([0.4])

# %%
output = np.dot(input_value, weights)

# %%
output
# Out:
# np.float64(2.0)
