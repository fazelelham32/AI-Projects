# %% [markdown]
# <a href="https://colab.research.google.com/github/fazelelham32/YouTube-Projects/blob/CNN-Projects-google-colab/NN_chapter3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **project3**

# %%
import numpy as np

# %%
inputs = np.array([0, 0])
b = np.array([-1.5, -.5])

# %%
weights = np.array([[1, 1] , [1, 1]])

# %%
and_or = np.dot(weights, inputs) + b.T
and_or
# Out:
# array([-1.5, -0.5])

# %%
if and_or[0] > 0:
    and_or[0] = 1
else:
   and_or[0] = 0

if and_or[1] > 0:
    and_or[1] = 1
else:
    and_or[1] = 0

# %%
and_or
# Out:
# array([0., 0.])

# %%
weights_xor = np.array([-1, 1])

# %%
xor = np.dot(weights_xor, and_or)
xor
# Out:
# np.float64(0.0)

# %%
if xor > 0:
    xor = 1
else:
    xor = 0

# %%
xor
# Out:
# 0

# %%
input = np.array([1, 2, 4, 6, 32, 65])

# %%
weight = np.array([0.5, 0.4, 1, 0.60, 0.50, 0.6])

# %%
np.dot(weight, input)
# Out:
# np.float64(63.9)

# %%
weight = np.array([[0.5, 0.4, 1, 0.60, 0.50, 0.6],
                   [0.5, 0.4, 1, 0.60, 0.50, 0.6],
                   [0.5, 0.4, 1, 0.60, 0.50, 0.6]])

# %%
out_put1 = np.dot(weight, input)

# %%
weight_2 = np.array([[0.5, 0.12, 0.32],
                     [0.5, 0.12, 0.32],
                     [0.5, 0.12, 0.32]])

# %%
out_put2 = np.dot(weight_2, out_put1)

# %%
out_put2
# Out:
# array([60.066, 60.066, 60.066])
